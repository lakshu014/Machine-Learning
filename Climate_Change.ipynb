# %% [markdown]
# # PROBLEM STATEMENT

# %% [markdown]
# <table>
#   <tr><td>
#     <img src="https://static01.nyt.com/images/2019/09/20/climate/20cli-protests-slide-XMBG/20cli-protests-slide-XMBG-videoSixteenByNine3000.jpg"
#          alt="People doing twitter things"  width="600">
#   </td></tr>
#   <tr><td align="center">
#     <b>Figure 1. People, man!
#   </td></tr>
# </table>

# %% [markdown]
# # STEP #0: IMPORT LIBRARIES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %% [markdown]
# # STEP #1: IMPORT dataSets

# %%
# You have to include the full link to the csv file containing your dataset
df = pd.read_csv('https://www.dropbox.com/s/0viviok98t2htx2/FAOSTAT_data_1-10-2022.csv?dl=1')

# %%
df.head(30)
# Out:
#    Domain Code              Domain  Area Code (FAO)         Area  \
# 0           ET  Temperature change                2  Afghanistan
# 1           ET  Temperature change                2  Afghanistan
# 2           ET  Temperature change                2  Afghanistan
# 3           ET  Temperature change                2  Afghanistan
# 4           ET  Temperature change                2  Afghanistan
# 5           ET  Temperature change                2  Afghanistan
# 6           ET  Temperature change                2  Afghanistan
# 7           ET  Temperature change                2  Afghanistan
# 8           ET  Temperature change                2  Afghanistan
# 9           ET  Temperature change                2  Afghanistan
# 10          ET  Temperature change                2  Afghanistan
# 11          ET  Temperature change                2  Afghanistan
# 12          ET  Temperature change                2  Afghanistan
# 13          ET  Temperature change                2  Afghanistan
# 14          ET  Temperature change                2  Afghanistan
# 15          ET  Temperature change                2  Afghanistan
# 16          ET  Temperature change                2  Afghanistan
# 17          ET  Temperature change                2  Afghanistan
# 18          ET  Temperature change                2  Afghanistan
# 19          ET  Temperature change                2  Afghanistan
# 20          ET  Temperature change                2  Afghanistan
# 21          ET  Temperature change                2  Afghanistan
# 22          ET  Temperature change                2  Afghanistan
# 23          ET  Temperature change                2  Afghanistan
# 24          ET  Temperature change                2  Afghanistan
# 25          ET  Temperature change                2  Afghanistan
# 26          ET  Temperature change                2  Afghanistan
# 27          ET  Temperature change                2  Afghanistan
# 28          ET  Temperature change                2  Afghanistan
# 29          ET  Temperature change                2  Afghanistan
#
#     Element Code             Element  Months Code   Months  Year Code  Year  \
# 0           7271  Temperature change         7001  January       1961  1961
# 1           7271  Temperature change         7001  January       1962  1962
# 2           7271  Temperature change         7001  January       1963  1963
# 3           7271  Temperature change         7001  January       1964  1964
# 4           7271  Temperature change         7001  January       1965  1965
# 5           7271  Temperature change         7001  January       1966  1966
# 6           7271  Temperature change         7001  January       1967  1967
# 7           7271  Temperature change         7001  January       1968  1968
# 8           7271  Temperature change         7001  January       1969  1969
# 9           7271  Temperature change         7001  January       1970  1970
# 10          7271  Temperature change         7001  January       1971  1971
# 11          7271  Temperature change         7001  January       1972  1972
# 12          7271  Temperature change         7001  January       1973  1973
# 13          7271  Temperature change         7001  January       1974  1974
# 14          7271  Temperature change         7001  January       1975  1975
# 15          7271  Temperature change         7001  January       1976  1976
# 16          7271  Temperature change         7001  January       1977  1977
# 17          7271  Temperature change         7001  January       1978  1978
# 18          7271  Temperature change         7001  January       1979  1979
# 19          7271  Temperature change         7001  January       1980  1980
# 20          7271  Temperature change         7001  January       1981  1981
# 21          7271  Temperature change         7001  January       1982  1982
# 22          7271  Temperature change         7001  January       1983  1983
# 23          7271  Temperature change         7001  January       1984  1984
# 24          7271  Temperature change         7001  January       1985  1985
# 25          7271  Temperature change         7001  January       1986  1986
# 26          7271  Temperature change         7001  January       1987  1987
# 27          7271  Temperature change         7001  January       1988  1988
# 28          7271  Temperature change         7001  January       1989  1989
# 29          7271  Temperature change         7001  January       1990  1990
#
#    Unit  Value Flag Flag Description
# 0    ?C  0.746   Fc  Calculated data
# 1    ?C  0.009   Fc  Calculated data
# 2    ?C  2.695   Fc  Calculated data
# 3    ?C -5.277   Fc  Calculated data
# 4    ?C  1.827   Fc  Calculated data
# 5    ?C  3.629   Fc  Calculated data
# 6    ?C -1.436   Fc  Calculated data
# 7    ?C  0.388   Fc  Calculated data
# 8    ?C -2.260   Fc  Calculated data
# 9    ?C  0.813   Fc  Calculated data
# 10   ?C -1.483   Fc  Calculated data
# 11   ?C -1.309   Fc  Calculated data
# 12   ?C -2.947   Fc  Calculated data
# 13   ?C -1.227   Fc  Calculated data
# 14   ?C -0.501   Fc  Calculated data
# 15   ?C  2.456   Fc  Calculated data
# 16   ?C -2.930   Fc  Calculated data
# 17   ?C -0.606   Fc  Calculated data
# 18   ?C  1.195   Fc  Calculated data
# 19   ?C -0.314   Fc  Calculated data
# 20   ?C  1.752   Fc  Calculated data
# 21   ?C  0.711   Fc  Calculated data
# 22   ?C  0.546   Fc  Calculated data
# 23   ?C -0.043   Fc  Calculated data
# 24   ?C  0.498   Fc  Calculated data
# 25   ?C  0.402   Fc  Calculated data
# 26   ?C  2.748   Fc  Calculated data
# 27   ?C  1.323   Fc  Calculated data
# 28   ?C -1.112   Fc  Calculated data
# 29   ?C  0.678   Fc  Calculated data

# %%
df.head(5)
# to define first five rows
# Out:
#   Domain Code              Domain  Area Code (FAO)         Area  Element Code  \
# 0          ET  Temperature change                2  Afghanistan          7271
# 1          ET  Temperature change                2  Afghanistan          7271
# 2          ET  Temperature change                2  Afghanistan          7271
# 3          ET  Temperature change                2  Afghanistan          7271
# 4          ET  Temperature change                2  Afghanistan          7271
#
#               Element  Months Code   Months  Year Code  Year Unit  Value Flag  \
# 0  Temperature change         7001  January       1961  1961   ?C  0.746   Fc
# 1  Temperature change         7001  January       1962  1962   ?C  0.009   Fc
# 2  Temperature change         7001  January       1963  1963   ?C  2.695   Fc
# 3  Temperature change         7001  January       1964  1964   ?C -5.277   Fc
# 4  Temperature change         7001  January       1965  1965   ?C  1.827   Fc
#
#   Flag Description
# 0  Calculated data
# 1  Calculated data
# 2  Calculated data
# 3  Calculated data
# 4  Calculated data

# %%
df.tail(10)
# to get last 10 rows in the dataset
# Out:
#        Domain Code              Domain  Area Code (FAO)      Area  \
# 229915          ET  Temperature change              181  Zimbabwe
# 229916          ET  Temperature change              181  Zimbabwe
# 229917          ET  Temperature change              181  Zimbabwe
# 229918          ET  Temperature change              181  Zimbabwe
# 229919          ET  Temperature change              181  Zimbabwe
# 229920          ET  Temperature change              181  Zimbabwe
# 229921          ET  Temperature change              181  Zimbabwe
# 229922          ET  Temperature change              181  Zimbabwe
# 229923          ET  Temperature change              181  Zimbabwe
# 229924          ET  Temperature change              181  Zimbabwe
#
#         Element Code             Element  Months Code               Months  \
# 229915          7271  Temperature change         7020  Meteorological year
# 229916          7271  Temperature change         7020  Meteorological year
# 229917          7271  Temperature change         7020  Meteorological year
# 229918          7271  Temperature change         7020  Meteorological year
# 229919          7271  Temperature change         7020  Meteorological year
# 229920          7271  Temperature change         7020  Meteorological year
# 229921          7271  Temperature change         7020  Meteorological year
# 229922          7271  Temperature change         7020  Meteorological year
# 229923          7271  Temperature change         7020  Meteorological year
# 229924          7271  Temperature change         7020  Meteorological year
#
#         Year Code  Year Unit  Value Flag Flag Description
# 229915       2011  2011   ?C  0.609   Fc  Calculated data
# 229916       2012  2012   ?C  0.720   Fc  Calculated data
# 229917       2013  2013   ?C  0.394   Fc  Calculated data
# 229918       2014  2014   ?C  0.507   Fc  Calculated data
# 229919       2015  2015   ?C  1.226   Fc  Calculated data
# 229920       2016  2016   ?C  1.470   Fc  Calculated data
# 229921       2017  2017   ?C  0.443   Fc  Calculated data
# 229922       2018  2018   ?C  0.747   Fc  Calculated data
# 229923       2019  2019   ?C  1.359   Fc  Calculated data
# 229924       2020  2020   ?C  0.820   Fc  Calculated data

# %%
df.info()
# it describes the not null objects
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229925 entries, 0 to 229924
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Domain Code       229925 non-null  object
#  1   Domain            229925 non-null  object
#  2   Area Code (FAO)   229925 non-null  int64
#  3   Area              229925 non-null  object
#  4   Element Code      229925 non-null  int64
#  5   Element           229925 non-null  object
#  6   Months Code       229925 non-null  int64
#  7   Months            229925 non-null  object
#  8   Year Code         229925 non-null  int64
#  9   Year              229925 non-null  int64
#  10  Unit              229925 non-null  object
#  11  Value             222012 non-null  float64
#  12  Flag              229925 non-null  object
#  13  Flag Description  229925 non-null  object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 24.6+ MB

# %%
df.describe()
# Out:
#        Area Code (FAO)  Element Code    Months Code      Year Code  \
# count    229925.000000      229925.0  229925.000000  229925.000000
# mean        130.647689        7271.0    7009.882353    1991.306248
# std          76.809008           0.0       6.037955      17.333252
# min           1.000000        7271.0    7001.000000    1961.000000
# 25%          64.000000        7271.0    7005.000000    1976.000000
# 50%         131.000000        7271.0    7009.000000    1992.000000
# 75%         194.000000        7271.0    7016.000000    2006.000000
# max         351.000000        7271.0    7020.000000    2020.000000
#
#                 Year          Value
# count  229925.000000  222012.000000
# mean     1991.306248       0.492626
# std        17.333252       1.036364
# min      1961.000000      -9.303000
# 25%      1976.000000      -0.071000
# 50%      1992.000000       0.414000
# 75%      2006.000000       0.999000
# max      2020.000000      11.759000

# %% [markdown]
# # STEP #2: CLEAN UP DATASET

# %%
df['Months Code'].unique()
# Out:
# array([7001, 7002, 7003, 7004, 7005, 7006, 7007, 7008, 7009, 7010, 7011,
#        7012, 7016, 7017, 7018, 7019, 7020])

# %%
df_new = df.drop(columns = ['Domain', 'Domain Code', 'Element Code', 'Element', 'Year Code', 'Unit','Area','Flag','Flag Description','Months'])
df_new = df_new[~df_new['Months Code'].isin([7016,7017,7018,7019])]

# %%
x = df_new[df_new['Months Code'] == 7020]

x[x['Value'].isnull()] 
x = x[['Area Code (FAO)','Year']]
g =df_new.copy()
for t in x.values:
  ind = x[ (x['Area Code (FAO)'] == t[0]) & (x['Year'] == t[1]) ].index
  g.drop(ind)

# %%
g
# Out:
#         Area Code (FAO)  Months Code  Year  Value
# 0                     2         7001  1961  0.746
# 1                     2         7001  1962  0.009
# 2                     2         7001  1963  2.695
# 3                     2         7001  1964 -5.277
# 4                     2         7001  1965  1.827
# ...                 ...          ...   ...    ...
# 229920              181         7020  2016  1.470
# 229921              181         7020  2017  0.443
# 229922              181         7020  2018  0.747
# 229923              181         7020  2019  1.359
# 229924              181         7020  2020  0.820
#
# [175825 rows x 4 columns]

# %%
from sklearn.impute import KNNImputer

ki = KNNImputer(n_neighbors= 6)

g1 = ki.fit_transform(g)

g1
# Out:
# array([[2.000e+00, 7.001e+03, 1.961e+03, 7.460e-01],
#        [2.000e+00, 7.001e+03, 1.962e+03, 9.000e-03],
#        [2.000e+00, 7.001e+03, 1.963e+03, 2.695e+00],
#        ...,
#        [1.810e+02, 7.020e+03, 2.018e+03, 7.470e-01],
#        [1.810e+02, 7.020e+03, 2.019e+03, 1.359e+00],
#        [1.810e+02, 7.020e+03, 2.020e+03, 8.200e-01]])

# %%
df_new = pd.DataFrame(g1, columns = ['Area Code','Months Code','Year','Value'])
df_new[['Area Code','Months Code','Year']] = df_new[['Area Code','Months Code','Year']].astype(int)
df_new
# Out:
#         Area Code  Months Code  Year  Value
# 0               2         7001  1961  0.746
# 1               2         7001  1962  0.009
# 2               2         7001  1963  2.695
# 3               2         7001  1964 -5.277
# 4               2         7001  1965  1.827
# ...           ...          ...   ...    ...
# 175820        181         7020  2016  1.470
# 175821        181         7020  2017  0.443
# 175822        181         7020  2018  0.747
# 175823        181         7020  2019  1.359
# 175824        181         7020  2020  0.820
#
# [175825 rows x 4 columns]

# %%
sns.heatmap(df_new.isnull(),yticklabels=False,cbar=False)
df_new.isnull().sum()
# Out:
# Area Code      0
# Months Code    0
# Year           0
# Value          0
# dtype: int64

# %%
x=df_new[df_new['Area Code'] ==  2]
x
# Out:
#      Area Code  Months Code  Year  Value
# 0            2         7001  1961  0.746
# 1            2         7001  1962  0.009
# 2            2         7001  1963  2.695
# 3            2         7001  1964 -5.277
# 4            2         7001  1965  1.827
# ..         ...          ...   ...    ...
# 775          2         7020  2016  1.581
# 776          2         7020  2017  1.626
# 777          2         7020  2018  1.682
# 778          2         7020  2019  1.125
# 779          2         7020  2020  0.652
#
# [780 rows x 4 columns]

# %% [markdown]
# # STEP #3: VISUALIZE DATASET

# %%
sns.pairplot(df_new)

# %%
x=df_new[df_new['Year'] == 1980]
x = x[x['Area Code'] == 2] 
plt.plot(x['Months Code'],x['Value'],linewidth =0.5)

# %%
X_numerical = df_new[['Year', 'Value']]

# %%
X_numerical
# Out:
#         Year  Value
# 0       1961  0.746
# 1       1962  0.009
# 2       1963  2.695
# 3       1964 -5.277
# 4       1965  1.827
# ...      ...    ...
# 175820  2016  1.470
# 175821  2017  0.443
# 175822  2018  0.747
# 175823  2019  1.359
# 175824  2020  0.820
#
# [175825 rows x 2 columns]

# %%
sns.pairplot(X_numerical)

# %%
sns.heatmap(X_numerical.corr(), annot =True)
# Out:
# <AxesSubplot:>

# %%
df_new
# Out:
#         Area Code  Months Code  Year  Value
# 0               2         7001  1961  0.746
# 1               2         7001  1962  0.009
# 2               2         7001  1963  2.695
# 3               2         7001  1964 -5.277
# 4               2         7001  1965  1.827
# ...           ...          ...   ...    ...
# 175820        181         7020  2016  1.470
# 175821        181         7020  2017  0.443
# 175822        181         7020  2018  0.747
# 175823        181         7020  2019  1.359
# 175824        181         7020  2020  0.820
#
# [175825 rows x 4 columns]

# %% [markdown]
# # STEP#4: CREATE TRAINING AND TESTING DATASET
# # STEP #5: TRAIN THE MODEL

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /Users/narasima/opt/anaconda3/lib/python3.9/site-packages (1.7.5)
# Requirement already satisfied: scipy in /Users/narasima/opt/anaconda3/lib/python3.9/site-packages (from xgboost) (1.7.3)
# Requirement already satisfied: numpy in /Users/narasima/opt/anaconda3/lib/python3.9/site-packages (from xgboost) (1.21.5)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score
from sklearn.tree import DecisionTreeRegressor 
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn import svm
import xgboost as xgb
# Out:
# 2023-05-18 10:31:32.199797: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def Scores(yt,pred):
    MAE = mean_absolute_error(y_true=yt,y_pred=pred)
    MSE = mean_squared_error(y_true=yt,y_pred=pred)
    R2 = r2_score(y_true=yt,y_pred=pred)
    return {'MAE': MAE, 'MSE': MSE,'R2-score': R2}

# %%
#Linear Regression
def lreg(xtn,xt,ytn,yt):
    lr = LinearRegression()
    lr.fit(xtn, ytn)
    pred = lr.predict(xt)
    return Scores(yt,pred)

# %%
from sklearn.preprocessing import PolynomialFeatures

def sreg(years,values):    
    # Reshape the data to fit the input requirements of LinearRegression
    X = years.reshape(-1, 1)

    # Create polynomial features of the sine function
    poly_features = PolynomialFeatures(degree=3)
    X_poly = poly_features.fit_transform(X)

    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X_poly, values, test_size=0.2, random_state=42)

    model = LinearRegression()
    model.fit(X_train, y_train)

    pred = model.predict(X_test)
    return Scores(y_test,pred)

# %%
#Decision Tree Regression
def dtreg(xtn,xt,ytn,yt):
    dtr = DecisionTreeRegressor(random_state=0)
    dtr.fit(xtn,ytn)
    pred = dtr.predict(xt)
    return Scores(yt,pred)

# %%
#RandomForest Regress
def rfreg(xtn,xt,ytn,yt):
    rfr = RandomForestRegressor(n_estimators=100,random_state=0)
    rfr.fit(xtn,ytn)
    pred = rfr.predict(xt)
    return Scores(yt,pred)

# %%
#SVM Regressor
def svreg(xtn,xt,ytn,yt):
    svr = svm.SVR(kernel='rbf', gamma='scale')
    svr.fit(xtn,ytn)
    pred = svr.predict(xt)
    return Scores(yt,pred)

# %%
#KNN Regressor
def knnreg(xtn,xt,ytn,yt):
    #finding the best k value
    k_range = list(range(1, 31))
    param_grid = dict(n_neighbors=k_range)
    knn_reg = KNeighborsRegressor()
    grid = GridSearchCV(knn_reg, param_grid, cv=10, scoring='neg_mean_squared_error')
    grid.fit(xtn, ytn)
    best_k = grid.best_params_['n_neighbors']
    
    #regress
    knn_reg = KNeighborsRegressor(n_neighbors=best_k)
    knn_reg.fit(xtn, ytn)
    pred = knn_reg.predict(xt)
    
    return Scores(yt,pred)

# %%
#XGBOOST 
def xgbreg(xtn,xt,ytn,yt):
    xgbreg = xgb.XGBRegressor()
    xgbreg.fit(xtn, ytn)
    pred = xgbreg.predict(xt)
    
    return Scores(yt,pred)

# %%
#Deep Neural Network
def dnn(xtn,xt,ytn,yt):
    input_dim = xtn.shape[1]
    model = Sequential()
    model.add(Dense(12, activation='relu', input_dim=input_dim))
    model.add(Dense(12, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    model.fit(xtn, ytn, epochs=10, batch_size=32, verbose=0)
    
    pred = model.predict(xt)
    return Scores(yt,pred)

# %%
Area = pd.DataFrame()
Area['Area'] = df['Area'].unique()
Area['Code'] = df['Area Code (FAO)'].unique()

# %%
from ipywidgets import interact,widgets
def Predict(x):
    
    # Filter data for specified country
    code = Area.loc[Area['Area'] == x, 'Code'].values[0]
    df = df_new[df_new['Area Code'] == code]
    
    # Prepare data for model training
    X = np.array(df['Year'].values).reshape(-1,1)
    Y = np.array(df['Value'].values).reshape(-1,1)
    
    split_data = train_test_split(X, Y, test_size = 0.3)
    benchmark = [
        lreg(*split_data),
        sreg(np.array(df['Year'].values),np.array(df['Value'].values)),
        dtreg(*split_data),
        rfreg(*split_data),
        svreg(*split_data),
        knnreg(*split_data),
        xgbreg(*split_data),
        dnn(*split_data)
    ]
    labels = ['LinearRegression','Sine Regression','Decision Tree','Random Forest','Support Vector Machines','K-nearest Neighbors','XGBoost','Deep Neural Neutral']
    col = ['MAE','MSE','R2-score']
    benchmark_table = pd.DataFrame(benchmark,index=labels,columns=col)
    table_widget = widgets.HTML(benchmark_table.to_html())
    display(table_widget)
    
    # Find the model with the best overall performance
    overall_scores = benchmark_table.mean(axis=1)
    best_model = overall_scores.idxmin()
    
    ax = benchmark_table.plot(kind='bar', rot=0, figsize=(10, 6))
    ax.set_title('Comparison of Model Scores')
    ax.set_xlabel('Model')
    ax.set_ylabel('Score')
    
    # Highlight the bars with the best overall performance
    highlight_label = 'Best Model'
    best_model_index = labels.index(best_model)
    ax.annotate(highlight_label, xy=(best_model_index, overall_scores[best_model]),
                xytext=(0, 3), textcoords='offset points',
                ha='center', va='bottom')
    # Adjust spacing between labels
    plt.xticks(range(len(labels)), labels, rotation=45, ha='right')
    plt.subplots_adjust(bottom=0.2)  # Adjust the bottom margin as needed

    # Display the plot
    plt.show()

# %%
interact(Predict, x =widgets.Dropdown(options = Area['Area'], description = 'Country Name: '))
# Out:
# /var/folders/l9/03t318lx3g96x545gs2vj3lh0000gn/T/ipykernel_2190/2201677819.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfr.fit(xtn,ytn)
# /Users/narasima/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 2023-05-18 10:31:39.951717: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 8/8 [==============================] - 0s 1ms/step
# HTML(value='<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></…
# <function __main__.Predict(x)>
